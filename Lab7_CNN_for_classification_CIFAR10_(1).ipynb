# %%
from google.colab import drive # Mount the google drive for data loading
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Import some related dependencies
# 1.   Numpy: a package for array transformation
# 2.   Scipy: a package for loading data with (.mat) format
# 3.   Matplotlib: a package for data visualization
# 4.   Skearn: a package including many machine learning approaches
# 5.   Tensorflow: a package for neural networks modeling
# 6.   Keras: a package for neural networks modeling which is established on Tensorflow

# %%
import numpy as np #helps for array operation
import scipy.io as sio #helps to read the data
import matplotlib.pyplot as plt #helps with graphical plots
from sklearn.preprocessing import OneHotEncoder #helps for label one-hot encoding
import keras #helps for CNN model construction
import tensorflow as tf #helps for CNN model construction

# %% [markdown]
# # Test the GPU

# %%
device_name = tf.test.gpu_device_name()  # Current GPU name
if device_name != '/device:GPU:0':       # Test if the GPU exists
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %% [markdown]
# # Load data using pandas package
# Data structure and data visualiazation

# %%
data = sio.loadmat('/content/drive/MyDrive/lab_code/Cifar10.mat') # Load the Cifar10.mat data
trainX = data['trainX']/255                                       # Scale training images from [0,255] to [0,1]
trainY = data['trainY']
testX = data['testX']/255                                         # Scale testing images from [0,255] to [0,1]
testY = data['testY']

print('Shape of trainX:', trainX.shape)
print('Shape of trainY:', trainY.shape)
print('Shape of testX:', testX.shape)
print('Shape of testY:', testY.shape)
# Out:
# Shape of trainX: (50000, 32, 32, 3)
# Shape of trainY: (50000, 1)
# Shape of testX: (10000, 32, 32, 3)
# Shape of testY: (10000, 1)

# %%
# Image visualization
ix = np.random.randint(0, trainX.shape[0], 7*7)				 		                    # Choose 7*7 random index
X = trainX[ix]		                                                            # Choose 7*7 samples as the selected index
plt.figure(figsize=(12,12))                                                   # Set the whole figure size
for i in range(7 * 7):           	                                            # Plot images
  plt.subplot(7, 7, 1 + i)                                                    # Define subplot
  plt.axis('off')									                                            # Turn off axis, only show the images
  plt.imshow(X[i])                                                            # Show the images
plt.show()

# %%
onehot = OneHotEncoder()                            #An objective for one-hot package
onehot.fit(trainY)                                  #Transform labels to be one-hot format
y_train_onehot = onehot.transform(trainY).toarray() #Transform training labels to be one-hot format
y_test_onehot = onehot.transform(testY).toarray()   #Transform testing labels to be one-hot format

# %%
y_train_onehot.shape
# Out:
# (50000, 10)

# %% [markdown]
# # Model training
# First, we will use a famous structure named LeNet-5 for model training.

# %%
# LeNet-5 model for model training
model = keras.Sequential()
model.add(keras.layers.Conv2D(filters=6, kernel_size=(5,5), strides=(1,1), padding='same', activation='relu', input_shape=(32, 32, 3)))  # The first convolutional layer. Input shape is 32x32x3 and activation function is Rectified Linear Unit (ReLU).\
                                                           # Kernel size and stride are set as (5,5) and (1,1), respectively. The number of convolutional kernels is 6. Besides, the zero padding is 'same', thus the output shape is (32/1) x (32/1) x 6 = 32x32x6, which is the same as the input shape.
model.add(keras.layers.MaxPool2D(pool_size=(2,2), strides=(2,2)))  # The first maxpooling layer. After the first convolutional layer, the maxpooling is performed, and the pool size and stride are both (2,2).
model.add(keras.layers.Conv2D(filters=16, kernel_size=(5,5), strides=(1,1), activation='relu')) # The second convolutional layer. The output shape is 12x12x16, where 12 = (16-5+1)/1.
model.add(keras.layers.MaxPool2D(pool_size=(2,2), strides=(2,2)))  # The second maxpooling layer. The pool size and stride are both (2,2). The output shape is 6x6x16, where 6 = (12-2)/2+1.
model.add(keras.layers.Flatten())                          # The previous output is flattened to be a vector with a size of 1x576.
model.add(keras.layers.Dense(120, activation='relu'))      # The first fully connected layer.
model.add(keras.layers.Dropout(0.3))                       # Dropout layer with a Dropout rate of 0.3
model.add(keras.layers.Dense(84, activation='relu'))       # The second fully connected layer.
model.add(keras.layers.Dropout(0.3))                       # Dropout layer with a Dropout rate of 0.3
model.add(keras.layers.Dense(10, activation='softmax'))    # The ouput layer. Softmax is used for probability estimation, which is suitable for classification tasks.
model.compile(tf.keras.optimizers.SGD(learning_rate = 1e-1), 'categorical_crossentropy', metrics='acc') # Model construction with a SGD optimizer, a categorical crossentropy loss function, and an accuracy metric.
model.summary() # Summary the constructed model.
model.fit(trainX, y_train_onehot, epochs = 100, batch_size = 1024, verbose = 2, validation_data = (testX, y_test_onehot)) # Model training with some hyperparameters
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 6)         456
#
#  max_pooling2d (MaxPooling2D  (None, 16, 16, 6)        0
#  )
#
#  conv2d_1 (Conv2D)           (None, 12, 12, 16)        2416
#
#  max_pooling2d_1 (MaxPooling  (None, 6, 6, 16)         0
#  2D)
#
#  flatten (Flatten)           (None, 576)               0
#
#  dense (Dense)               (None, 120)               69240
#
#  dropout (Dropout)           (None, 120)               0
#
#  dense_1 (Dense)             (None, 84)                10164
#
#  dropout_1 (Dropout)         (None, 84)                0
#
#  dense_2 (Dense)             (None, 10)                850
#
# =================================================================
# Total params: 83,126
# Trainable params: 83,126
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 49/49 - 12s - loss: 2.2943 - acc: 0.1292 - val_loss: 2.2786 - val_acc: 0.1829 - 12s/epoch - 241ms/step
# Epoch 2/100
# 49/49 - 1s - loss: 2.2643 - acc: 0.1549 - val_loss: 2.1655 - val_acc: 0.2465 - 1s/epoch - 29ms/step
# Epoch 3/100
# 49/49 - 1s - loss: 2.2312 - acc: 0.1752 - val_loss: 2.1266 - val_acc: 0.2729 - 1s/epoch - 28ms/step
# Epoch 4/100
# 49/49 - 1s - loss: 2.1556 - acc: 0.2113 - val_loss: 2.0425 - val_acc: 0.2981 - 1s/epoch - 28ms/step
# Epoch 5/100
# 49/49 - 1s - loss: 2.0959 - acc: 0.2336 - val_loss: 1.9234 - val_acc: 0.3169 - 1s/epoch - 29ms/step
# Epoch 6/100
# 49/49 - 1s - loss: 1.9929 - acc: 0.2690 - val_loss: 1.8064 - val_acc: 0.3537 - 1s/epoch - 28ms/step
# Epoch 7/100
# 49/49 - 1s - loss: 1.9311 - acc: 0.2936 - val_loss: 1.8229 - val_acc: 0.3524 - 1s/epoch - 28ms/step
# Epoch 8/100
# 49/49 - 1s - loss: 1.8623 - acc: 0.3198 - val_loss: 1.7398 - val_acc: 0.3691 - 1s/epoch - 29ms/step
# Epoch 9/100
# 49/49 - 1s - loss: 1.8078 - acc: 0.3367 - val_loss: 1.6905 - val_acc: 0.3859 - 1s/epoch - 28ms/step
# Epoch 10/100
# Epoch 29/100
# 49/49 - 1s - loss: 1.4569 - acc: 0.4720 - val_loss: 1.4419 - val_acc: 0.4830 - 1s/epoch - 29ms/step
# Epoch 30/100
# 49/49 - 1s - loss: 1.4417 - acc: 0.4809 - val_loss: 1.3585 - val_acc: 0.4964 - 1s/epoch - 29ms/step
# Epoch 31/100
# 49/49 - 1s - loss: 1.4417 - acc: 0.4786 - val_loss: 1.3912 - val_acc: 0.4997 - 1s/epoch - 29ms/step
# Epoch 32/100
# 49/49 - 1s - loss: 1.4313 - acc: 0.4833 - val_loss: 1.3356 - val_acc: 0.5085 - 1s/epoch - 28ms/step
# Epoch 33/100
# 49/49 - 1s - loss: 1.4198 - acc: 0.4869 - val_loss: 1.3308 - val_acc: 0.5203 - 1s/epoch - 29ms/step
# Epoch 34/100
# 49/49 - 1s - loss: 1.4089 - acc: 0.4924 - val_loss: 1.3509 - val_acc: 0.5098 - 1s/epoch - 29ms/step
# Epoch 35/100
# 49/49 - 1s - loss: 1.4021 - acc: 0.4934 - val_loss: 1.3656 - val_acc: 0.5027 - 1s/epoch - 29ms/step
# Epoch 36/100
# 49/49 - 1s - loss: 1.3975 - acc: 0.4979 - val_loss: 1.3816 - val_acc: 0.5046 - 1s/epoch - 29ms/step
# Epoch 37/100
# 49/49 - 1s - loss: 1.3853 - acc: 0.5013 - val_loss: 1.3133 - val_acc: 0.5228 - 1s/epoch - 29ms/step
# Epoch 38/100
# 49/49 - 1s - loss: 1.3791 - acc: 0.5040 - val_loss: 1.4600 - val_acc: 0.4861 - 1s/epoch - 29ms/step
# Epoch 39/100
# 49/49 - 1s - loss: 1.3707 - acc: 0.5079 - val_loss: 1.2986 - val_acc: 0.5256 - 1s/epoch - 29ms/step
# Epoch 40/100
# 49/49 - 1s - loss: 1.3598 - acc: 0.5096 - val_loss: 1.2981 - val_acc: 0.5282 - 1s/epoch - 28ms/step
# Epoch 41/100
# 49/49 - 1s - loss: 1.3584 - acc: 0.5113 - val_loss: 1.2941 - val_acc: 0.5349 - 1s/epoch - 28ms/step
# Epoch 42/100
# 49/49 - 1s - loss: 1.3418 - acc: 0.5188 - val_loss: 1.3230 - val_acc: 0.5266 - 1s/epoch - 29ms/step
# Epoch 43/100
# 49/49 - 1s - loss: 1.3433 - acc: 0.5175 - val_loss: 1.2811 - val_acc: 0.5377 - 1s/epoch - 29ms/step
# Epoch 44/100
# 49/49 - 2s - loss: 1.3292 - acc: 0.5224 - val_loss: 1.3090 - val_acc: 0.5324 - 2s/epoch - 32ms/step
# Epoch 45/100
# 49/49 - 1s - loss: 1.3264 - acc: 0.5245 - val_loss: 1.2895 - val_acc: 0.5380 - 1s/epoch - 30ms/step
# Epoch 46/100
# 49/49 - 1s - loss: 1.3184 - acc: 0.5268 - val_loss: 1.2735 - val_acc: 0.5423 - 1s/epoch - 29ms/step
# Epoch 47/100
# 49/49 - 1s - loss: 1.3214 - acc: 0.5287 - val_loss: 1.2618 - val_acc: 0.5440 - 1s/epoch - 29ms/step
# Epoch 48/100
# 49/49 - 1s - loss: 1.2973 - acc: 0.5327 - val_loss: 1.2621 - val_acc: 0.5485 - 1s/epoch - 28ms/step
# Epoch 49/100
# 49/49 - 1s - loss: 1.3085 - acc: 0.5324 - val_loss: 1.2333 - val_acc: 0.5577 - 1s/epoch - 29ms/step
# Epoch 50/100
# 49/49 - 1s - loss: 1.2862 - acc: 0.5414 - val_loss: 1.2779 - val_acc: 0.5411 - 1s/epoch - 29ms/step
# Epoch 51/100
# 49/49 - 1s - loss: 1.2877 - acc: 0.5399 - val_loss: 1.2192 - val_acc: 0.5624 - 1s/epoch - 29ms/step
# Epoch 52/100
# 49/49 - 1s - loss: 1.2764 - acc: 0.5428 - val_loss: 1.2356 - val_acc: 0.5595 - 1s/epoch - 29ms/step
# Epoch 53/100
# 49/49 - 1s - loss: 1.2714 - acc: 0.5455 - val_loss: 1.2560 - val_acc: 0.5504 - 1s/epoch - 29ms/step
# Epoch 54/100
# 49/49 - 1s - loss: 1.2641 - acc: 0.5495 - val_loss: 1.2383 - val_acc: 0.5535 - 1s/epoch - 29ms/step
# Epoch 55/100
# 49/49 - 1s - loss: 1.2619 - acc: 0.5516 - val_loss: 1.2284 - val_acc: 0.5590 - 1s/epoch - 29ms/step
# Epoch 56/100
# 49/49 - 1s - loss: 1.2536 - acc: 0.5521 - val_loss: 1.2598 - val_acc: 0.5493 - 1s/epoch - 29ms/step
# Epoch 57/100
# 49/49 - 1s - loss: 1.2457 - acc: 0.5580 - val_loss: 1.2246 - val_acc: 0.5655 - 1s/epoch - 29ms/step
# Epoch 58/100
# 49/49 - 1s - loss: 1.2444 - acc: 0.5576 - val_loss: 1.2194 - val_acc: 0.5624 - 1s/epoch - 29ms/step
# Epoch 59/100
# 49/49 - 1s - loss: 1.2355 - acc: 0.5615 - val_loss: 1.2285 - val_acc: 0.5637 - 1s/epoch - 29ms/step
# Epoch 60/100
# 49/49 - 1s - loss: 1.2380 - acc: 0.5597 - val_loss: 1.1831 - val_acc: 0.5780 - 1s/epoch - 29ms/step
# Epoch 61/100
# 49/49 - 1s - loss: 1.2261 - acc: 0.5670 - val_loss: 1.1949 - val_acc: 0.5755 - 1s/epoch - 29ms/step
# Epoch 62/100
# 49/49 - 1s - loss: 1.2076 - acc: 0.5689 - val_loss: 1.2116 - val_acc: 0.5733 - 1s/epoch - 29ms/step
# Epoch 63/100
# 49/49 - 1s - loss: 1.2191 - acc: 0.5650 - val_loss: 1.2281 - val_acc: 0.5639 - 1s/epoch - 29ms/step
# Epoch 64/100
# 49/49 - 1s - loss: 1.2046 - acc: 0.5708 - val_loss: 1.1810 - val_acc: 0.5819 - 1s/epoch - 29ms/step
# Epoch 65/100
# 49/49 - 2s - loss: 1.1989 - acc: 0.5744 - val_loss: 1.1875 - val_acc: 0.5752 - 2s/epoch - 32ms/step
# Epoch 66/100
# 49/49 - 1s - loss: 1.2014 - acc: 0.5754 - val_loss: 1.1781 - val_acc: 0.5788 - 1s/epoch - 29ms/step
# Epoch 67/100
# 49/49 - 1s - loss: 1.1756 - acc: 0.5797 - val_loss: 1.2426 - val_acc: 0.5580 - 1s/epoch - 29ms/step
# Epoch 68/100
# 49/49 - 1s - loss: 1.1848 - acc: 0.5796 - val_loss: 1.1718 - val_acc: 0.5834 - 1s/epoch - 29ms/step
# Epoch 69/100
# 49/49 - 1s - loss: 1.1654 - acc: 0.5844 - val_loss: 1.1522 - val_acc: 0.5916 - 1s/epoch - 29ms/step
# Epoch 70/100
# 49/49 - 1s - loss: 1.1767 - acc: 0.5834 - val_loss: 1.1606 - val_acc: 0.5863 - 1s/epoch - 30ms/step
# Epoch 71/100
# 49/49 - 1s - loss: 1.1603 - acc: 0.5884 - val_loss: 1.2567 - val_acc: 0.5626 - 1s/epoch - 29ms/step
# Epoch 72/100
# 49/49 - 1s - loss: 1.1672 - acc: 0.5853 - val_loss: 1.1396 - val_acc: 0.5932 - 1s/epoch - 29ms/step
# Epoch 73/100
# 49/49 - 1s - loss: 1.1628 - acc: 0.5884 - val_loss: 1.2473 - val_acc: 0.5611 - 1s/epoch - 29ms/step
# Epoch 74/100
# 49/49 - 1s - loss: 1.1479 - acc: 0.5938 - val_loss: 1.1459 - val_acc: 0.5942 - 1s/epoch - 29ms/step
# Epoch 75/100
# 49/49 - 1s - loss: 1.1480 - acc: 0.5919 - val_loss: 1.2084 - val_acc: 0.5725 - 1s/epoch - 29ms/step
# Epoch 76/100
# 49/49 - 1s - loss: 1.1371 - acc: 0.5964 - val_loss: 1.1288 - val_acc: 0.6000 - 1s/epoch - 29ms/step
# Epoch 77/100
# 49/49 - 1s - loss: 1.1367 - acc: 0.5966 - val_loss: 1.1445 - val_acc: 0.5933 - 1s/epoch - 29ms/step
# Epoch 78/100
# 49/49 - 2s - loss: 1.1312 - acc: 0.6014 - val_loss: 1.1274 - val_acc: 0.6005 - 2s/epoch - 32ms/step
# Epoch 79/100
# 49/49 - 1s - loss: 1.1291 - acc: 0.6008 - val_loss: 1.1241 - val_acc: 0.6039 - 1s/epoch - 29ms/step
# Epoch 80/100
# 49/49 - 1s - loss: 1.1302 - acc: 0.5999 - val_loss: 1.1346 - val_acc: 0.5999 - 1s/epoch - 30ms/step
# Epoch 81/100
# 49/49 - 1s - loss: 1.1228 - acc: 0.6026 - val_loss: 1.1410 - val_acc: 0.5968 - 1s/epoch - 29ms/step
# Epoch 82/100
# 49/49 - 1s - loss: 1.1103 - acc: 0.6087 - val_loss: 1.1844 - val_acc: 0.5864 - 1s/epoch - 29ms/step
# Epoch 83/100
# 49/49 - 1s - loss: 1.1227 - acc: 0.6042 - val_loss: 1.1700 - val_acc: 0.5876 - 1s/epoch - 29ms/step
# Epoch 84/100
# 49/49 - 1s - loss: 1.1136 - acc: 0.6037 - val_loss: 1.1098 - val_acc: 0.6097 - 1s/epoch - 29ms/step
# Epoch 85/100
# 49/49 - 2s - loss: 1.0923 - acc: 0.6156 - val_loss: 1.1705 - val_acc: 0.5916 - 2s/epoch - 36ms/step
# Epoch 86/100
# 49/49 - 2s - loss: 1.1090 - acc: 0.6065 - val_loss: 1.1849 - val_acc: 0.5935 - 2s/epoch - 33ms/step
# Epoch 87/100
# 49/49 - 2s - loss: 1.0977 - acc: 0.6099 - val_loss: 1.1112 - val_acc: 0.6107 - 2s/epoch - 32ms/step
# Epoch 88/100
# 49/49 - 2s - loss: 1.0889 - acc: 0.6120 - val_loss: 1.1361 - val_acc: 0.6032 - 2s/epoch - 32ms/step
# Epoch 89/100
# 49/49 - 1s - loss: 1.0740 - acc: 0.6185 - val_loss: 1.1496 - val_acc: 0.5928 - 1s/epoch - 29ms/step
# Epoch 90/100
# 49/49 - 1s - loss: 1.0757 - acc: 0.6190 - val_loss: 1.1891 - val_acc: 0.5892 - 1s/epoch - 29ms/step
# Epoch 91/100
# 49/49 - 1s - loss: 1.0736 - acc: 0.6202 - val_loss: 1.1380 - val_acc: 0.6037 - 1s/epoch - 29ms/step
# Epoch 92/100
# 49/49 - 1s - loss: 1.0662 - acc: 0.6207 - val_loss: 1.1072 - val_acc: 0.6119 - 1s/epoch - 29ms/step
# Epoch 93/100
# 49/49 - 1s - loss: 1.0747 - acc: 0.6198 - val_loss: 1.1043 - val_acc: 0.6046 - 1s/epoch - 29ms/step
# Epoch 94/100
# 49/49 - 2s - loss: 1.0684 - acc: 0.6238 - val_loss: 1.0995 - val_acc: 0.6156 - 2s/epoch - 32ms/step
# Epoch 95/100
# 49/49 - 1s - loss: 1.0599 - acc: 0.6254 - val_loss: 1.1009 - val_acc: 0.6118 - 1s/epoch - 29ms/step
# Epoch 96/100
# 49/49 - 1s - loss: 1.0517 - acc: 0.6255 - val_loss: 1.1156 - val_acc: 0.6067 - 1s/epoch - 29ms/step
# Epoch 97/100
# 49/49 - 1s - loss: 1.0483 - acc: 0.6308 - val_loss: 1.1285 - val_acc: 0.6086 - 1s/epoch - 29ms/step
# Epoch 98/100
# 49/49 - 1s - loss: 1.0517 - acc: 0.6276 - val_loss: 1.1451 - val_acc: 0.6035 - 1s/epoch - 29ms/step
# Epoch 99/100
# 49/49 - 1s - loss: 1.0350 - acc: 0.6364 - val_loss: 1.1113 - val_acc: 0.6131 - 1s/epoch - 29ms/step
# Epoch 100/100
# 49/49 - 2s - loss: 1.0475 - acc: 0.6298 - val_loss: 1.1069 - val_acc: 0.6173 - 2s/epoch - 33ms/step

# %% [markdown]
# #Model testing

# %%
prediction = model.predict(testX)            # Prediction of the testing set
print (model.evaluate(testX, y_test_onehot)) # Evaluation of the prediction
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 1.1069 - acc: 0.6173
# [1.1069457530975342, 0.6172999739646912]

# %% [markdown]
# # A Deep CNN Model
# In order to improve the prediction accuracy, we will use a more complicated model structure to compare with LeNet-5.

# %%
model = keras.Sequential()

model.add(keras.layers.Conv2D(filters=32, kernel_size=(3, 3), strides=(1,1), input_shape=(32, 32, 3), activation='relu', padding='same'))  # 32 convolutional filters are used, kernel size is (3, 3) and strides are (1, 1). 'same' padding is used.
model.add(keras.layers.BatchNormalization())                   # Batch Normalization to accelerate the model convergence.
model.add(keras.layers.Conv2D(filters=32, kernel_size=(3, 3), strides=(1,1), input_shape=(32, 32, 3), activation='relu', padding='same'))  # 32 convolutional filters are used, kernel size is (3, 3) and strides are (1, 1). 'same' padding is used.
model.add(keras.layers.BatchNormalization())                   # Batch Normalization to accelerate the model convergence.
model.add(keras.layers.MaxPool2D(pool_size=(2, 2), strides=(2,2)))   # Pooling size is (2, 2) and strides is (2, 2).
model.add(keras.layers.BatchNormalization())                   # Batch Normalization to accelerate the model convergence.
model.add(keras.layers.Dropout(0.25))                          # Dropout layer with a Dropout rate of 0.25.

model.add(keras.layers.Conv2D(filters=64, kernel_size=(3, 3), strides=(1,1), input_shape=(32, 32, 3), activation='relu', padding='same'))   # 32 convolutional filters are used, kernel size is (3, 3) and strides are (1, 1). 'same' padding is used.
model.add(keras.layers.BatchNormalization())                   # Batch Normalization to accelerate the model convergence.
model.add(keras.layers.Conv2D(filters=64, kernel_size=(3, 3), strides=(1,1), input_shape=(32, 32, 3), activation='relu', padding='same'))   # 32 convolutional filters are used, kernel size is (3, 3) and strides are (1, 1). 'same' padding is used.
model.add(keras.layers.BatchNormalization())                   # Batch Normalization to accelerate the model convergence.
model.add(keras.layers.MaxPool2D(pool_size=(2, 2), strides=(2,2)))   # Pooling size is (2, 2) and strides is (2, 2).
model.add(keras.layers.Dropout(0.25))                          # Dropout layer with a Dropout rate of 0.25.

model.add(keras.layers.Conv2D(filters=128, kernel_size=(3, 3), strides=(1,1), input_shape=(32, 32, 3), activation='relu', padding='same'))  # 32 convolutional filters are used, kernel size is (3, 3) and strides are (1, 1). 'same' padding is used.
model.add(keras.layers.BatchNormalization())                   # Batch Normalization to accelerate the model convergence.
model.add(keras.layers.Conv2D(filters=128, kernel_size=(3, 3), strides=(1,1), input_shape=(32, 32, 3), activation='relu', padding='same'))  # 32 convolutional filters are used, kernel size is (3, 3) and strides are (1, 1). 'same' padding is used.
model.add(keras.layers.BatchNormalization())                   # Batch Normalization to accelerate the model convergence.
model.add(keras.layers.MaxPool2D(pool_size=(2, 2), strides=(2,2)))   # Pooling size is (2, 2) and strides is (2, 2).
model.add(keras.layers.Dropout(0.25))                          # Dropout layer with a Dropout rate of 0.25.

model.add(keras.layers.Flatten())                              # The output data is flattened to be a vector.
model.add(keras.layers.Dense(128, activation='relu'))          # Fully connected layer with 128 output neurons.
model.add(keras.layers.Dropout(0.25))                          # Dropout layer with a Dropout rate of 0.25.
model.add(keras.layers.Dense(10, activation='softmax'))        # Output layer with 10 neurons, i.e., 10 classes.
model.compile(tf.keras.optimizers.SGD(learning_rate = 1e-1), 'categorical_crossentropy', metrics='acc')  # Model construction with a SGD optimizer, a categorical crossentropy loss function, and an accuracy metric.
model.summary() # Summary the constructed model.
model.fit(trainX, y_train_onehot, epochs = 100, batch_size = 1024, verbose = 2, validation_data = (testX, y_test_onehot)) # Model training with some hyperparameters
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  batch_normalization (BatchN  (None, 32, 32, 32)       128
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 32)        9248
#
#  batch_normalization_1 (Batc  (None, 32, 32, 32)       128
#  hNormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 16, 16, 32)       0
#  )
#
#  dropout (Dropout)           (None, 16, 16, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 64)        18496
#
#  batch_normalization_2 (Batc  (None, 16, 16, 64)       256
#  hNormalization)
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 64)        36928
#
#  batch_normalization_3 (Batc  (None, 16, 16, 64)       256
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 8, 8, 64)         0
#  2D)
#
#  dropout_1 (Dropout)         (None, 8, 8, 64)          0
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 128)         73856
#
#  batch_normalization_4 (Batc  (None, 8, 8, 128)        512
#  hNormalization)
#
#  conv2d_5 (Conv2D)           (None, 8, 8, 128)         147584
#
#  batch_normalization_5 (Batc  (None, 8, 8, 128)        512
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 4, 4, 128)        0
#  2D)
#
#  dropout_2 (Dropout)         (None, 4, 4, 128)         0
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 128)               262272
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 552,362
# Trainable params: 551,466
# Non-trainable params: 896
# _________________________________________________________________
# Epoch 1/100
# 49/49 - 22s - loss: 2.4507 - acc: 0.2883 - val_loss: 2.4160 - val_acc: 0.1068 - 22s/epoch - 453ms/step
# Epoch 2/100
# 49/49 - 12s - loss: 1.6468 - acc: 0.3960 - val_loss: 2.8150 - val_acc: 0.1039 - 12s/epoch - 246ms/step
# Epoch 3/100
# 49/49 - 12s - loss: 1.4925 - acc: 0.4532 - val_loss: 3.0310 - val_acc: 0.1430 - 12s/epoch - 247ms/step
# Epoch 4/100
# 49/49 - 12s - loss: 1.3931 - acc: 0.4920 - val_loss: 2.9516 - val_acc: 0.1765 - 12s/epoch - 246ms/step
# Epoch 5/100
# 49/49 - 12s - loss: 1.3095 - acc: 0.5227 - val_loss: 2.9595 - val_acc: 0.1865 - 12s/epoch - 246ms/step
# Epoch 6/100
# 49/49 - 12s - loss: 1.2300 - acc: 0.5562 - val_loss: 2.6025 - val_acc: 0.2347 - 12s/epoch - 246ms/step
# Epoch 7/100
# 49/49 - 12s - loss: 1.1628 - acc: 0.5812 - val_loss: 2.2258 - val_acc: 0.2794 - 12s/epoch - 246ms/step
# Epoch 8/100
# 49/49 - 12s - loss: 1.1104 - acc: 0.6048 - val_loss: 1.5533 - val_acc: 0.4537 - 12s/epoch - 246ms/step
# Epoch 9/100
# 49/49 - 12s - loss: 0.2845 - acc: 0.8990 - val_loss: 0.5824 - val_acc: 0.8258 - 12s/epoch - 248ms/step
# Epoch 85/100
# 49/49 - 12s - loss: 0.2801 - acc: 0.8985 - val_loss: 0.5415 - val_acc: 0.8383 - 12s/epoch - 248ms/step
# Epoch 86/100
# 49/49 - 12s - loss: 0.2724 - acc: 0.9013 - val_loss: 0.5636 - val_acc: 0.8310 - 12s/epoch - 247ms/step
# Epoch 87/100
# 49/49 - 12s - loss: 0.2735 - acc: 0.9008 - val_loss: 0.5530 - val_acc: 0.8342 - 12s/epoch - 246ms/step
# Epoch 88/100
# 49/49 - 12s - loss: 0.2684 - acc: 0.9023 - val_loss: 0.5715 - val_acc: 0.8281 - 12s/epoch - 246ms/step
# Epoch 89/100
# 49/49 - 12s - loss: 0.2682 - acc: 0.9040 - val_loss: 0.5849 - val_acc: 0.8274 - 12s/epoch - 246ms/step
# Epoch 90/100
# 49/49 - 12s - loss: 0.2659 - acc: 0.9035 - val_loss: 0.5515 - val_acc: 0.8363 - 12s/epoch - 246ms/step
# Epoch 91/100
# 49/49 - 12s - loss: 0.2616 - acc: 0.9063 - val_loss: 0.5627 - val_acc: 0.8333 - 12s/epoch - 246ms/step
# Epoch 92/100
# 49/49 - 12s - loss: 0.2592 - acc: 0.9066 - val_loss: 0.5626 - val_acc: 0.8346 - 12s/epoch - 246ms/step
# Epoch 93/100
# 49/49 - 12s - loss: 0.2562 - acc: 0.9076 - val_loss: 0.5366 - val_acc: 0.8426 - 12s/epoch - 249ms/step
# Epoch 94/100
# 49/49 - 12s - loss: 0.2526 - acc: 0.9077 - val_loss: 0.5480 - val_acc: 0.8377 - 12s/epoch - 247ms/step
# Epoch 95/100
# 49/49 - 12s - loss: 0.2511 - acc: 0.9088 - val_loss: 0.5666 - val_acc: 0.8311 - 12s/epoch - 247ms/step
# Epoch 96/100
# 49/49 - 12s - loss: 0.2453 - acc: 0.9124 - val_loss: 0.5423 - val_acc: 0.8395 - 12s/epoch - 246ms/step
# Epoch 97/100
# 49/49 - 12s - loss: 0.2389 - acc: 0.9141 - val_loss: 0.5717 - val_acc: 0.8372 - 12s/epoch - 246ms/step
# Epoch 98/100
# 49/49 - 12s - loss: 0.2402 - acc: 0.9127 - val_loss: 0.5705 - val_acc: 0.8320 - 12s/epoch - 246ms/step
# Epoch 99/100
# 49/49 - 12s - loss: 0.2366 - acc: 0.9150 - val_loss: 0.7768 - val_acc: 0.7929 - 12s/epoch - 249ms/step
# Epoch 100/100
# 49/49 - 12s - loss: 0.2368 - acc: 0.9128 - val_loss: 0.5573 - val_acc: 0.8364 - 12s/epoch - 246ms/step

# %% [markdown]
# # Model testing

# %%
prediction = model.predict(testX)            # Prediction of the testing set
print (model.evaluate(testX, y_test_onehot)) # Evaluation of the prediction
# Out:
# 313/313 [==============================] - 3s 8ms/step - loss: 2.3033 - acc: 0.0999
# [2.3032824993133545, 0.09989999979734421]
